# %% [markdown]
# <a href="https://colab.research.google.com/github/AbitovR/-Financial-Planning/blob/main/Forecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Descriptiopn: Predict the future of a stoock using FB Pr and Python

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fac912c7-11c4-45d3-b548-447c5501506b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fac912c7-11c4-45d3-b548-447c5501506b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TSLA (1).csv to TSLA (1).csv
# ...

# %%
df = pd.read_csv('TSLA (1).csv')

# %%
df
# Out:
#             Date          Open  ...     Adj Close        Volume
# 0     2016-10-14    637.007996  ...    640.377991  5.814460e+07
# 1     2016-10-15    640.310974  ...    638.645996  3.903540e+07
# 2     2016-10-16    639.083008  ...    641.630981  4.029810e+07
# 3     2016-10-17    641.817993  ...    639.192993  5.806360e+07
# 4     2016-10-18    639.411011  ...    637.960022  6.554670e+07
# ...          ...           ...  ...           ...           ...
# 1822  2021-10-10  54952.820313  ...  54771.578125  3.952779e+10
# 1823  2021-10-11  54734.125000  ...  57484.789063  4.263733e+10
# 1824  2021-10-12  57526.832031  ...  56041.058594  4.108376e+10
# 1825  2021-10-13  56038.257813  ...  57401.097656  4.168425e+10
# 1826  2021-10-14  57491.265625  ...  57323.117188  4.084210e+10
#
# [1827 rows x 7 columns]

# %%
#Select the date and price
df = df[['Date','Close']]
#rename the features:
df = df.rename(columns={'Date':'ds','Close':'y'})
#show the data
df
# Out:
#               ds            y
# 0     2010-06-29     4.778000
# 1     2010-06-30     4.766000
# 2     2010-07-01     4.392000
# 3     2010-07-02     3.840000
# 4     2010-07-06     3.222000
# ...          ...          ...
# 2851  2021-10-25  1024.859985
# 2852  2021-10-26  1018.429993
# 2853  2021-10-27  1037.859985
# 2854  2021-10-28  1077.040039
# 2855  2021-10-29  1114.000000
#
# [2856 rows x 2 columns]

# %%
#Getting the last 20 rows of data and store then into a new variable
last = df[len(df)-20:]
last
# Out:
#               ds            y
# 2836  2021-10-04   781.530029
# 2837  2021-10-05   780.590027
# 2838  2021-10-06   782.750000
# 2839  2021-10-07   793.609985
# 2840  2021-10-08   785.489990
# 2841  2021-10-11   791.940002
# 2842  2021-10-12   805.719971
# 2843  2021-10-13   811.080017
# 2844  2021-10-14   818.320007
# 2845  2021-10-15   843.030029
# 2846  2021-10-18   870.109985
# 2847  2021-10-19   864.270020
# 2848  2021-10-20   865.799988
# 2849  2021-10-21   894.000000
# 2850  2021-10-22   909.679993
# 2851  2021-10-25  1024.859985
# 2852  2021-10-26  1018.429993
# 2853  2021-10-27  1037.859985
# 2854  2021-10-28  1077.040039
# 2855  2021-10-29  1114.000000

# %%
#Get all of the rows in the data se texcept for the last 20 rows of data
df = df[:-20]
df
# Out:
#               ds           y
# 0     2010-06-29    4.778000
# 1     2010-06-30    4.766000
# 2     2010-07-01    4.392000
# 3     2010-07-02    3.840000
# 4     2010-07-06    3.222000
# ...          ...         ...
# 2831  2021-09-27  791.359985
# 2832  2021-09-28  777.559998
# 2833  2021-09-29  781.309998
# 2834  2021-09-30  775.479980
# 2835  2021-10-01  775.219971
#
# [2836 rows x 2 columns]

# %%
# Importing FB prophet library
from fbprophet import Prophet
#creating the model
fbp = Prophet(daily_seasonality = True)
# Fit or train the model
fbp.fit(df)
future = fbp.make_future_dataframe(periods=365)
forecast = fbp.predict(future)

# %%
#Import the facebooks prophet plotting libraries
from fbprophet.plot import plot_plotly
#plot the data
plot_plotly(fbp, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6dad4504-72eb-4861-ad1b-c99cd3246d5b" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6dad4504-72eb-4861-ad1b-c99cd3246d5b")) {
#                     Plotly.newPlot(
#                         '6dad4504-72eb-4861-ad1b-c99cd3246d5b',
# ...

# %%
#Show the models prediction for 10-30-2021
forecast[forecast.ds == '2021-10-10']['yhat']
# Out:
# 2844    804.549068
# Name: yhat, dtype: float64

# %%
last[last.ds == '2021-10-10']['y']
# Out:
# Series([], Name: y, dtype: float64)
